# %%
import sys
sys.path.insert(0, '..')
from utils.cargar import df_caso
from utils.preprocesamiento import process_df, procesar_adela

caso = 'adela'
df = df_caso(caso,chat=True)
df.head()
# Out:
#        user_id  team_id gender  df  \
# id
# 91531     9490   3900.0      M   1
# 91532     9505   3886.0      M   1
# 91533     9506   3888.0      M   1
# 91534     9506   3888.0      M   1
# 91535     9513   3902.0      M   1
#
#                                                    title  \
# id
# 91531  [Acordar entre todas/os la respuesta, discutie...
# 91532  [Acordar entre todas/os la respuesta, discutie...
# 91533  [Acordar entre todas/os la respuesta, discutie...
# 91534  [Acordar entre todas/os la respuesta, discutie...
# 91535  [Acordar entre todas/os la respuesta, discutie...
#
#                                    opt_left  \
# id
# 91531  Preservar el recurso natural escaso.
# 91532  Preservar el recurso natural escaso.
# 91533  Preservar el recurso natural escaso.
# 91534  Preservar el recurso natural escaso.
# 91535  Preservar el recurso natural escaso.
#
#                                       opt_right        message  phase  \
# id
# ...

# %%
df['phase'].value_counts()
# Out:
# phase
# 3    7656
# 2    6674
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))
