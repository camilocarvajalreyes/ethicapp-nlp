# %%
import sys
sys.path.insert(0, '..')
from utils.cargar import df_caso

caso = 'adela'
df = df_caso(caso,chat=True,verbose=True)
df.head()
# Out:
# Secciones encontradas:
# 	 2021.CD2201.09.chat.csv
# 	 2021.CD2201.10.chat.csv
# 	 2021.CD2201.02.chat.csv
# 	 2021.CD2201.06.chat.csv
# 	 2021.CD2201.01.chat.csv
# 	 2021.CD2201.05.chat.csv
# 	 2021.CD2201.07.chat.csv
# 	 2022.CD1201.01.chat.csv
# 	 2022.CD1201.10.chat.csv
# 	 2022.CD1201.03.chat.csv
# 	 2022.CD1201.05.chat.csv
# 	 2023.CD1100.09.chat.csv
# 	 2023.CD1100.05.chat.csv
# 	 2023.CD1100.04.chat.csv
# 	 2023.CD1100.08.chat.csv
# 	 2023.CD1100.03.chat.csv
# 	 2023.CD1100.10.chat.csv
# 	 2023.CD1100.02.chat.csv
# 	 2023.CD1100.07.chat.csv
# 	 2023.CD1100.06.chat.csv
#        user_id  team_id gender  df  \
# id
# 55568     4433   2415.0      F   1
# 55569     4435   2416.0      M   1
# 55570     4424   2416.0      M   1
# 55571     4419   2413.0      F   1
# 55572     4434   2412.0      F   1
#
#                                                    title  \
# id
# 55568  [Proporcione argumentos para justificar su res...
# 55569  [Proporcione argumentos para justificar su res...
# 55570  [Proporcione argumentos para justificar su res...
# 55571  [Proporcione argumentos para justificar su res...
# 55572  [Proporcione argumentos para justificar su res...
#
#                                               opt_left  \
# id
# 55568  Producir el alimento contra  déficit vitamínico
# 55569  Producir el alimento contra  déficit vitamínico
# 55570  Producir el alimento contra  déficit vitamínico
# 55571  Producir el alimento contra  déficit vitamínico
# 55572  Producir el alimento contra  déficit vitamínico
#
#                                      opt_right     message  phase  \
# id
# 55568  Resguardar las tradiciones identitarias        hola      3
# 55569  Resguardar las tradiciones identitarias        Hola      3
# 55570  Resguardar las tradiciones identitarias  hola grupo      3
# 55571  Resguardar las tradiciones identitarias         alo      3
# 55572  Resguardar las tradiciones identitarias       holaa      3
#
#                            time  reply_to        curso  seccion
# id
# 55568  2021-12-01T00:15:26.928Z       NaN  2021.CD2201        9
# 55569  2021-12-01T00:15:27.413Z       NaN  2021.CD2201        9
# 55570  2021-12-01T00:15:29.963Z       NaN  2021.CD2201        9
# 55571  2021-12-01T00:15:37.360Z       NaN  2021.CD2201        9
# 55572  2021-12-01T00:15:37.449Z       NaN  2021.CD2201        9

# %%
df['phase'].value_counts()
# Out:
# phase
# 3    11766
# 2     6820
# 4     2073
# 5      491
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))

# %% [markdown]
# ---
# Alicia

# %%
caso = 'alicia'
df = df_caso(caso,chat=True,verbose=True)
df.head()
# Out:
# Secciones encontradas:
# 	 2021.CD1201.09.chat.csv
# 	 2021.CD1201.05.chat.csv
# 	 2021.CD1201.04.chat.csv
# 	 2021.CD1201.06.chat.csv
# 	 2021.CD1201.07.chat.csv
# 	 2021.CD1201.03.chat.csv
# 	 2021.CD1201.08.chat.csv
# 	 2021.CD1100.02.chat.csv
#        user_id  team_id gender  df  \
# id
# 45350     2626   2072.0      F   1
# 45351     2888   2077.0      F   1
# 45352     2888   2077.0      F   1
# 45353     2551   2076.0      M   1
# 45354     2653   2082.0      F   1
#
#                                                    title  \
# id
# 45350  [Acordar entre todas/os la respuesta, discutie...
# 45351  [Acordar entre todas/os la respuesta, discutie...
# 45352  [Acordar entre todas/os la respuesta, discutie...
# 45353  [Acordar entre todas/os la respuesta, discutie...
# 45354  [Acordar entre todas/os la respuesta, discutie...
#
#                                                 opt_left  \
# id
# 45350  Los criterios técnicos del proyecto y de los u...
# 45351  Los criterios técnicos del proyecto y de los u...
# 45352  Los criterios técnicos del proyecto y de los u...
# 45353  Los criterios técnicos del proyecto y de los u...
# 45354  Los criterios técnicos del proyecto y de los u...
#
#                                opt_right              message  phase  \
# id
# 45350  Los plazos acordados del proyecto                 hola      3
# 45351  Los plazos acordados del proyecto                 Hola      3
# 45352  Los plazos acordados del proyecto                  uwu      3
# 45353  Los plazos acordados del proyecto  Hola genteeeeeeeeee      3
# 45354  Los plazos acordados del proyecto                holaa      3
#
#                            time  reply_to        curso  seccion
# id
# 45350  2021-11-03T21:32:40.436Z       NaN  2021.CD1201        9
# 45351  2021-11-03T21:32:43.870Z       NaN  2021.CD1201        9
# 45352  2021-11-03T21:32:44.883Z       NaN  2021.CD1201        9
# 45353  2021-11-03T21:32:46.716Z       NaN  2021.CD1201        9
# 45354  2021-11-03T21:32:47.532Z       NaN  2021.CD1201        9

# %%
df['phase'].value_counts()
# Out:
# phase
# 3    6745
# 4    4262
# 5     662
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))

# %% [markdown]
# ---
# Julieta

# %%
caso = 'julieta'
df = df_caso(caso,chat=True,verbose=True)
df.head()
# Out:
# Secciones encontradas:
# 	 2021.CD1100.04.chat.csv
# 	 2021.CD1100.08.chat.csv
# 	 2021.CD1100.06.chat.csv
# 	 2021.CD1100.07.chat.csv
# 	 2021.CD1100.03.chat.csv
# 	 2021.CD1100.09.chat.csv
# 	 2021.CD1100.01.chat.csv
# 	 2021.CD1100.02.chat.csv
#        user_id  team_id gender  df  \
# id
# 25846     2953   1624.0      M   1
# 25849     2926   1612.0      F   1
# 25850     2787   1642.0      F   1
# 25853     3171   1640.0      M   1
# 25858     2790   1642.0      F   1
#
#                                                    title  \
# id
# 25846  [Acordar entre todas/os la respuesta, discutie...
# 25849  [Acordar entre todas/os la respuesta, discutie...
# 25850  [Acordar entre todas/os la respuesta, discutie...
# 25853  [Acordar entre todas/os la respuesta, discutie...
# 25858  [Acordar entre todas/os la respuesta, discutie...
#
#                                         opt_left  \
# id
# 25846  Usar la información del grupo de WhatsApp
# 25849  Usar la información del grupo de WhatsApp
# 25850  Usar la información del grupo de WhatsApp
# 25853  Usar la información del grupo de WhatsApp
# 25858  Usar la información del grupo de WhatsApp
#
#                                           opt_right        message  phase  \
# id
# 25846  No usar la información del grupo de WhatsApp           hola      4
# 25849  No usar la información del grupo de WhatsApp           hola      4
# 25850  No usar la información del grupo de WhatsApp  holaa equipoo      4
# 25853  No usar la información del grupo de WhatsApp     Holaaaaaaa      4
# 25858  No usar la información del grupo de WhatsApp          holi?      4
#
#                            time  reply_to        curso  seccion
# id
# 25846  2021-05-26T17:29:51.667Z       NaN  2021.CD1100        4
# 25849  2021-05-26T17:29:53.374Z       NaN  2021.CD1100        4
# 25850  2021-05-26T17:29:53.453Z       NaN  2021.CD1100        4
# 25853  2021-05-26T17:29:55.042Z       NaN  2021.CD1100        4
# 25858  2021-05-26T17:29:56.538Z       NaN  2021.CD1100        4

# %%
df['phase'].value_counts()
# Out:
# phase
# 4    10225
# 5     2981
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))

# %% [markdown]
# ---
# Laura

# %%
caso = 'laura'
df = df_caso(caso,chat=True,verbose=True)
df.head()
# Out:
# Secciones encontradas:
# 	 2020.CD2201.10.chat.csv
# 	 2020.CD2201.04.chat.csv
# 	 2020.CD2201.01.chat.csv
# 	 2020.CD2201.07.chat.csv
# 	 2020.CD2201.09.chat.csv
# 	 2020.CD2201.06.chat.csv
#       user_id  team_id gender  df  \
# id
# 9269     1900   1065.0      M   1
# 9270     1885   1065.0      M   1
# 9271     1893   1065.0      M   1
# 9272     1890   1065.0      M   1
# 9273     1885   1065.0      M   1
#
#                                                   title            opt_left  \
# id
# 9269  Es adecuado que Laura le dedique paulatinament...  Ajustar dedicación
# 9270  Es adecuado que Laura le dedique paulatinament...  Ajustar dedicación
# 9271  Es adecuado que Laura le dedique paulatinament...  Ajustar dedicación
# 9272  Es adecuado que Laura le dedique paulatinament...  Ajustar dedicación
# 9273  Es adecuado que Laura le dedique paulatinament...  Ajustar dedicación
#
#                 opt_right         message  phase                      time  \
# id
# 9269  Mantener dedicación            holi      4  2020-10-09T21:21:12.898Z
# 9270  Mantener dedicación            holi      4  2020-10-09T21:21:19.071Z
# 9271  Mantener dedicación            holi      4  2020-10-09T21:21:19.423Z
# 9272  Mantener dedicación            hola      4  2020-10-09T21:21:22.877Z
# 9273  Mantener dedicación  cuantos somos?      4  2020-10-09T21:21:25.401Z
#
#       reply_to        curso  seccion
# id
# 9269       NaN  2020.CD2201       10
# 9270       NaN  2020.CD2201       10
# 9271       NaN  2020.CD2201       10
# 9272       NaN  2020.CD2201       10
# 9273       NaN  2020.CD2201       10

# %%
df['phase'].value_counts()
# Out:
# phase
# 3    2467
# 4     394
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))

# %% [markdown]
# ---

# %%
import sys
sys.path.insert(0, '..')
from utils.cargar import df_caso

caso = 'amanda'
df = df_caso(caso,chat=True,verbose=True)
df.head()
# Out:
# Secciones encontradas:
# 	 2023.CD1201.09.chat.csv
# 	 2023.CD1201.08.chat.csv
# 	 2023.CD1201.04.chat.csv
# 	 2023.CD1201.03.chat.csv
# 	 2023.CD1201.05.chat.csv
# 	 2023.CD1201.07.chat.csv
# 	 2023.CD1201.02.chat.csv
#        user_id  team_id gender  df  \
# id
# 97488     9857   4076.0      M   1
# 97489     9852   4079.0      F   1
# 97490     9856   4073.0      F   1
# 97491     9857   4076.0      M   1
# 97492     9850   4073.0      M   1
#
#                                                    title  \
# id
# 97488  [Acordar entre todas/os la respuesta, discutie...
# 97489  [Acordar entre todas/os la respuesta, discutie...
# 97490  [Acordar entre todas/os la respuesta, discutie...
# 97491  [Acordar entre todas/os la respuesta, discutie...
# 97492  [Acordar entre todas/os la respuesta, discutie...
#
#                                                 opt_left  \
# id
# 97488  Algoritmo X: menor error detectando la enferme...
# 97489  Algoritmo X: menor error detectando la enferme...
# 97490  Algoritmo X: menor error detectando la enferme...
# 97491  Algoritmo X: menor error detectando la enferme...
# 97492  Algoritmo X: menor error detectando la enferme...
#
#                                                opt_right message  phase  \
# id
# 97488  Algoritmo Y: mayor error detectando la enferme...    hols      2
# 97489  Algoritmo Y: mayor error detectando la enferme...    HOLA      2
# 97490  Algoritmo Y: mayor error detectando la enferme...       a      2
# 97491  Algoritmo Y: mayor error detectando la enferme...      cs      2
# 97492  Algoritmo Y: mayor error detectando la enferme...    hola      2
#
#                            time  reply_to        curso  seccion
# id
# 97488  2023-11-13T21:21:24.178Z       NaN  2023.CD1201        9
# 97489  2023-11-13T21:21:28.256Z       NaN  2023.CD1201        9
# 97490  2023-11-13T21:21:28.675Z       NaN  2023.CD1201        9
# 97491  2023-11-13T21:21:30.553Z       NaN  2023.CD1201        9
# 97492  2023-11-13T21:21:31.076Z       NaN  2023.CD1201        9

# %%
df['phase'].value_counts()
# Out:
# phase
# 2    4824
# 3    2068
# Name: count, dtype: int64

# %%
df.to_csv("datos_EthicApp/MDS7201/{}_chat.csv".format(caso))
